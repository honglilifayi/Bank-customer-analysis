# %%
# Load the Bank.csv data and separate columns by a semicolon, header = 0 so the first row will be the names of attributes.
import pandas as pd
bank = pd.read_csv('Bank.csv', sep = ';',decimal = '.', header = 0)
print(bank)
# Out:
#        age            job   marital            education  default  housing  \
# 0     30.0    blue-collar   married             basic.9y       no      yes
# 1     39.0       services    single          high.school       no       no
# 2     25.0       services   married          high.school       no      yes
# 3     38.0       services   married             basic.9y       no  unknown
# 4     47.0         admin.   married    university.degree       no      yes
# 5     32.0       services    single    university.degree       no       no
# 6     32.0         admin.    single    university.degree       no      yes
# 7     41.0   entrepreneur   married    university.degree  unknown      yes
# 8     31.0       services  divorced  professional.course       no       no
# 9     35.0    blue-collar   married             basic.9y  unknown       no
# 10    25.0       services    single             basic.6y  unknown      yes
# 11    36.0  self-employed    single             basic.4y       no       no
# 12    36.0         admin.   married          high.school       no       no
# 13    47.0    blue-collar   married             basic.4y       no      yes
# 14    29.0         admin.    single          high.school       no       no
# 15    27.0       services    single    university.degree       no       no
# 16    44.0         admin.  divorced    university.degree       no       no
# 17    46.0         admin.  divorced    university.degree       no      yes
# 18    45.0   entrepreneur   married    university.degree  unknown      yes
# 19    50.0    blue-collar   married             basic.4y       no       no
# 20    55.0       services   married             basic.6y  unknown      yes
# 21    39.0     technician  divorced          high.school       no       no
# 22    29.0     technician    single    university.degree       no      yes
# 23    40.0     management   married          high.school       no       no
# 24    44.0     technician   married  professional.course  unknown      yes
# 25    38.0     technician   married  professional.course       no      yes
# 26    36.0     technician  divorced  professional.course       no       no
# 27    28.0    blue-collar   married             basic.6y  unknown       no
# 28    47.0         admin.    single              unknown  unknown       no
# 29    34.0         admin.   married    university.degree       no       no
# ...    ...            ...       ...                  ...      ...      ...
# 4089  25.0         admin.    single    university.degree       no      yes
# 4090  43.0    blue-collar   married             basic.4y  unknown      yes
# 4091  38.0     management   married          high.school  unknown       no
# 4092  30.0    blue-collar    single          high.school       no       no
# 4093  56.0        retired   married             basic.4y  unknown       no
# 4094  62.0    blue-collar   married             basic.4y       no      yes
# 4095  36.0         admin.    single    university.degree       no       no
# 4096  33.0       services   married          high.school       no       no
# 4097  41.0    blue-collar  divorced             basic.9y       no       no
# 4098  34.0      housemaid    single    university.degree       no      yes
# 4099  58.0         admin.  divorced          high.school       no       no
# 4100  41.0         admin.  divorced          high.school       no       no
# 4101  35.0   entrepreneur    single    university.degree       no      yes
# 4102  31.0    blue-collar    single             basic.9y  unknown       no
# 4103  43.0       services   married          high.school       no       no
# 4104  42.0     technician  divorced  professional.course       no      yes
# 4105  47.0      housemaid   married             basic.4y  unknown      yes
# 4106  45.0   entrepreneur  divorced             basic.9y       no      yes
# 4107  36.0         admin.   married    university.degree  unknown      yes
# 4108  32.0         admin.   married    university.degree       no      yes
# 4109  63.0        retired   married          high.school       no       no
# 4110  53.0      housemaid  divorced             basic.6y  unknown  unknown
# 4111  30.0     technician   married    university.degree       no       no
# 4112  31.0     technician    single  professional.course       no      yes
# 4113  31.0         admin.    single    university.degree       no      yes
# 4114  30.0         admin.   married             basic.6y       no      yes
# 4115  39.0         admin.   married          high.school       no      yes
# 4116  27.0        student    single          high.school       no       no
# 4117  58.0         admin.   married          high.school       no       no
# 4118  34.0     management    single          high.school       no      yes
#
#          loan    contact month day_of_week ...   campaign  pdays previous  \
# 0          no   cellular   may         fri ...        2.0    999        0
# 1          no  telephone   may         fri ...        4.0    999        0
# 2          no  telephone   jun         wed ...        1.0    999        0
# 3     unknown  telephone   jun         fri ...        3.0    999        0
# 4          no   cellular   nov         mon ...        1.0    999        0
# 5          no   cellular   sep         thu ...        3.0    999        2
# 6          no   cellular   sep         mon ...        4.0    999        0
# 7          no   cellular   nov         mon ...        2.0    999        0
# 8          no   cellular   nov         tue ...        1.0    999        1
# 9          no  telephone   may         thu ...        1.0    999        0
# 10         no   cellular   jul         thu ...        1.0    999        0
# 11         no   cellular   jul         thu ...        1.0    999        0
# 12         no  telephone   may         wed ...        2.0    999        0
# 13         no  telephone   jun         thu ...        2.0    999        0
# 14         no   cellular   may         fri ...        2.0    999        0
# 15         no   cellular   jul         wed ...        2.0    999        0
# 16         no   cellular   jul         wed ...        6.0    999        0
# 17         no  telephone   jul         mon ...        4.0    999        0
# 18        yes   cellular   aug         mon ...        2.0    999        0
# 19        yes   cellular   jul         tue ...        1.0    999        0
# 20         no   cellular   jul         tue ...        6.0    999        0
# 21         no   cellular   mar         mon ...        1.0     12        2
# 22        yes   cellular   aug         wed ...        3.0    999        0
# 23        yes   cellular   aug         wed ...        1.0    999        0
# 24         no  telephone   may         fri ...        7.0    999        0
# 25         no   cellular   aug         mon ...        1.0    999        0
# 26         no  telephone   may         wed ...        1.0    999        0
# 27         no   cellular   may         mon ...        2.0    999        1
# 28         no  telephone   may         thu ...        1.0    999        0
# 29         no   cellular   aug         tue ...        1.0    999        0
# ...       ...        ...   ...         ... ...        ...    ...      ...
# 4089      yes   cellular   oct         fri ...        1.0    999        1
# 4090      yes  telephone   may         tue ...        2.0    999        0
# 4091       no  telephone   may         thu ...        2.0    999        0
# 4092       no  telephone   jul         wed ...        1.0    999        0
# 4093       no   cellular   jul         tue ...        3.0    999        0
# 4094       no   cellular   nov         mon ...        1.0      6        1
# 4095      yes   cellular   aug         fri ...        2.0    999        0
# 4096       no  telephone   may         mon ...        2.0    999        0
# 4097       no   cellular   aug         tue ...        1.0    999        0
# 4098       no   cellular   aug         thu ...        3.0    999        0
# 4099       no   cellular   aug         tue ...        1.0    999        0
# 4100       no   cellular   apr         fri ...        1.0    999        0
# 4101       no   cellular   jul         mon ...        5.0    999        0
# 4102      yes  telephone   jun         fri ...        2.0    999        0
# 4103       no  telephone   may         mon ...        1.0    999        0
# 4104       no   cellular   aug         mon ...        1.0    999        0
# 4105       no  telephone   jul         tue ...        2.0    999        0
# 4106       no   cellular   may         tue ...        3.0    999        0
# 4107       no   cellular   aug         wed ...       11.0    999        0
# 4108       no  telephone   may         thu ...        5.0    999        0
# 4109       no   cellular   oct         wed ...        1.0    999        0
# 4110  unknown  telephone   may         fri ...        2.0    999        0
# 4111      yes   cellular   jun         fri ...        1.0    999        1
# 4112       no   cellular   nov         thu ...        1.0    999        0
# 4113       no   cellular   nov         thu ...        1.0    999        0
# 4114      yes   cellular   jul         thu ...        1.0    999        0
# 4115       no  telephone   jul         fri ...        1.0    999        0
# 4116       no   cellular   may         mon ...        2.0    999        1
# 4117       no   cellular   aug         fri ...        1.0    999        0
# 4118       no   cellular   nov         wed ...        1.0    999        0
#
#          poutcome emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  \
# 0     nonexistent         -1.8         92.893          -46.2      1.313
# 1     nonexistent          1.1         93.994          -36.4      4.855
# 2     nonexistent          1.4         94.465          -41.8      4.962
# 3     nonexistent          1.4         94.465          -41.8      4.959
# 4     nonexistent         -0.1         93.200          -42.0      4.191
# 5         failure         -1.1         94.199          -37.5      0.884
# 6     nonexistent         -1.1         94.199          -37.5      0.879
# 7     nonexistent         -0.1         93.200          -42.0      4.191
# 8         failure         -0.1         93.200          -42.0      4.153
# 9     nonexistent          1.1         93.994          -36.4      4.855
# 10    nonexistent          1.4         93.918          -42.7      4.958
# 11    nonexistent          1.4         93.918          -42.7      4.968
# 12    nonexistent          1.1         93.994          -36.4      4.859
# 13    nonexistent          1.4         94.465          -41.8      4.958
# 14    nonexistent         -1.8         92.893          -46.2      1.313
# 15    nonexistent          1.4         93.918          -42.7      4.963
# 16    nonexistent          1.4         93.918          -42.7      4.957
# 17    nonexistent          1.4         93.918          -42.7      4.962
# 18    nonexistent          1.4         93.444          -36.1      4.965
# 19    nonexistent          1.4         93.918          -42.7      4.961
# 20    nonexistent          1.4         93.918          -42.7      4.962
# 21        success         -1.8         93.369          -34.8      0.639
# 22    nonexistent          1.4         93.444          -36.1      4.967
# 23    nonexistent          1.4         93.444          -36.1      4.965
# 24    nonexistent          1.1         93.994          -36.4      4.864
# 25    nonexistent          1.4         93.444          -36.1      4.965
# 26    nonexistent          1.1         93.994          -36.4      4.856
# 27        failure         -1.8         92.893          -46.2      1.299
# 28    nonexistent          1.1         93.994          -36.4       4.86
# 29    nonexistent          1.4         93.444          -36.1      4.963
# ...           ...          ...            ...            ...        ...
# 4089      failure         -3.4         92.431          -26.9      0.739
# 4090  nonexistent          1.1         93.994          -36.4      4.857
# 4091  nonexistent          1.1         93.994          -36.4       4.86
# 4092  nonexistent          1.4         93.918          -42.7      4.956
# 4093  nonexistent          1.4         93.918          -42.7      4.961
# 4094      success         -3.4         92.649          -30.1      0.719
# 4095  nonexistent          1.4         93.444          -36.1      4.963
# 4096  nonexistent          1.1         93.994          -36.4      4.857
# 4097  nonexistent          1.4         93.444          -36.1      4.963
# 4098  nonexistent          1.4         93.444          -36.1      4.963
# 4099  nonexistent          1.4         93.444          -36.1      4.963
# 4100  nonexistent         -1.8         93.075          -47.1      1.405
# 4101  nonexistent          1.4         93.918          -42.7       4.96
# 4102  nonexistent          1.4         94.465          -41.8      4.959
# 4103  nonexistent          1.1         93.994          -36.4      4.857
# 4104  nonexistent          1.4         93.444          -36.1       4.97
# 4105  nonexistent          1.4         93.918          -42.7      4.961
# 4106  nonexistent         -1.8         92.893          -46.2      1.344
# 4107  nonexistent          1.4         93.444          -36.1      4.964
# 4108  nonexistent         -1.8         92.893          -46.2      1.266
# 4109  nonexistent         -3.4         92.431          -26.9       0.74
# 4110  nonexistent          1.1         93.994          -36.4      4.855
# 4111      failure         -1.7         94.055          -39.8      0.748
# 4112  nonexistent         -0.1         93.200          -42.0      4.076
# 4113  nonexistent         -0.1         93.200          -42.0      4.076
# 4114  nonexistent          1.4         93.918          -42.7      4.958
# 4115  nonexistent          1.4         93.918          -42.7      4.959
# 4116      failure         -1.8         92.893          -46.2      1.354
# 4117  nonexistent          1.4         93.444          -36.1      4.966
# 4118  nonexistent         -0.1         93.200          -42.0       4.12
#
#      nr.employed    y
# 0         5099.1   no
# 1           5191   no
# 2         5228.1   no
# 3         5228.1   no
# 4         5195.8   no
# 5         4963.6   no
# 6         4963.6   no
# 7         5195.8   no
# 8         5195.8   no
# 9           5191   no
# 10        5228.1   no
# 11        5228.1   no
# 12          5191   no
# 13        5228.1   no
# 14        5099.1   no
# 15        5228.1   no
# 16        5228.1   no
# 17        5228.1   no
# 18        5228.1   no
# 19        5228.1  yes
# 20        5228.1   no
# 21           NaN  yes
# 22        5228.1   no
# 23        5228.1   no
# 24          5191   no
# 25        5228.1  yes
# 26          5191   no
# 27        5099.1   no
# 28          5191   no
# 29        5228.1   no
# ...          ...  ...
# 4089      5017.5  yes
# 4090        5191   no
# 4091        5191   no
# 4092      5228.1   no
# 4093      5228.1   no
# 4094      5017.5   no
# 4095      5228.1   no
# 4096        5191   no
# 4097      5228.1   no
# 4098      5228.1   no
# 4099      5228.1   no
# 4100      5099.1   no
# 4101      5228.1   no
# 4102      5228.1   no
# 4103        5191   no
# 4104      5228.1   no
# 4105      5228.1   no
# 4106      5099.1   no
# 4107      5228.1   no
# 4108      5099.1   no
# 4109      5017.5   no
# 4110        5191   no
# 4111      4991.6   no
# 4112      5195.8   no
# 4113      5195.8   no
# 4114      5228.1   no
# 4115      5228.1   no
# 4116      5099.1   no
# 4117      5228.1   no
# 4118      5195.8   no
#
# [4119 rows x 21 columns]

# %%
# check datatypes f loaded data
bank.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays              object
# previous           object
# poutcome           object
# emp.var.rate       object
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m          object
# nr.employed        object
# y                  object
# dtype: object

# %%
# according to description, pdays and previous should be numerical variables instead of object, check into these two columns
bank['pdays'].value_counts()
# Out:
# 999            3955
# 3                52
# 6                42
# 4                14
# 7                10
# 10                8
# 12                5
# 5                 4
# 0                 4
# 2                 4
# 9                 3
# 1                 3
# 13                2
# 15                2
# 16                2
# 18                2
# 11                1
# 14                1
# nonexistent       1
# 17                1
# -36.4             1
# 19                1
# 21                1
# Name: pdays, dtype: int64

# %%
# The pdays column contains a value "nonexistent"which should be a member of the adjacent column "poutcome"
bank['poutcome'].value_counts()
# Out:
# nonexistent    3519
# failure         454
# success         142
# 5191              1
# 1.4               1
# -1.8              1
# 93.918            1
# Name: poutcome, dtype: int64

# %%
# Further look into the column "poutcome", this should be an attribute contains only categorical results "failure, success, nonexistent".
# But now the printed results contain numerical values which may be values from later columns.
# So far it can be induced that values haven been shifted forwards in some rows,
# this may result in rest of the row contains blank-values where it didn't mean to be.
# can verify this by checking if the last few columns have the same number of rows as the bank dataset.
bank.shape
# Out:
# (4119, 21)

# %%
print(bank['euribor3m'].count())
print(bank['nr.employed'].count())
print(bank['y'].count())
# the bank dataset has 4119 rows whereas the last three columns have less rows, means there missing values in these columns,
# but these missing values could be caused by dislocated values.
# Out:
# 4116
# 4115
# 4115

# %%
# check if the first few columns also have abnormal values
bank['marital'].value_counts()
# the marital column does contain a clustered value "divorceded”;”basic.9y", which shifts the rest values of the row towards left.
# Out:
# married                  2509
# single                   1153
# divorced                  445
# unknown                    11
# divorceded”;”basic.9y       1
# Name: marital, dtype: int64

# %%
bank['education'].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                573
# professional.course     535
# basic.4y                429
# basic.6y                227
# unknown                 167
# no                        1
# illiterate                1
# basic.6yes”;”no           1
# Name: education, dtype: int64

# %%
# most of the columns contain some shifted values which is caused by some values containing incorrect quotes that cannot be read
# replace these incorrect quotes with the correct ones
# open the bank file and assign it to another name, 
with open('Bank.csv') as f:
    s = f.read()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-3956ab13ec8c> in <module>()
#       2 # replace these incorrect quotes with the correct ones
#       3 # open the bank file and assign it to another name,
# ----> 4 with open('Bank.csv') as f:
#       5     s = f.read()
#
# IOError: [Errno 2] No such file or directory: 'Bank.csv'

# %%
# replace ” by "
rep = s.replace('”', '"')

# %%
# open the file with new name and overwrite it with name fw
fw = open('Banknew.csv', 'w')
fw.write(rep)
fw.close()
f.close()

# %%
# read the newfile Banknew to load the replaced data
bk = pd.read_csv('Banknew.csv', sep = ';',decimal = '.')

# %%
bk['marital'].value_counts()
# Out:
# married       2509
# single        1153
# divorced       445
# unknown         11
# divorceded       1
# Name: marital, dtype: int64

# %%
bk['education'].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                574
# professional.course     535
# basic.4y                429
# basic.6y                227
# unknown                 167
# basic.6yes                1
# illiterate                1
# Name: education, dtype: int64

# %%
bk['default'].value_counts()
# the incorrect quotes have been removed but there are typos like "noo" , "divorceded", "basic.6yes" need to be fixed
# Out:
# no         3314
# unknown     803
# noo           1
# yes           1
# Name: default, dtype: int64

# %%
# now the loaded data bk should have the same data types as the source data.
bk['default'].value_counts()
# Out:
# no         3314
# unknown     803
# noo           1
# yes           1
# Name: default, dtype: int64

# %%
# the attribute "duration" is still shown as object because it contains other typos such as "-".
bk['duration'].value_counts()
# Out:
# 77      24
# 112     23
# 73      22
# 81      21
# 83      20
# 122     20
# 113     20
# 90      20
# 145     20
# 135     19
# 131     19
# 114     19
# 88      19
# 103     18
# 107     18
# 159     18
# 87      18
# 155     18
# 69      17
# 139     17
# 147     17
# 102     17
# 204     17
# 111     17
# 161     17
# 180     17
# 160     17
# 130     17
# 95      17
# 126     16
#         ..
# 838      1
# 775      1
# 366      1
# 696      1
# 693      1
# 1114     1
# -        1
# 868      1
# 1167     1
# 867      1
# 764      1
# 882      1
# 881      1
# 886      1
# 888      1
# 1150     1
# 739      1
# 325      1
# 662      1
# 776      1
# 771      1
# 770      1
# 1386     1
# 1046     1
# 479      1
# 1119     1
# 667      1
# 1149     1
# 663      1
# 3253     1
# Name: duration, Length: 829, dtype: int64

# %%
# now check from the first categorical attribute to see if there is any typos
bk['job'].value_counts()
# Out:
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: job, dtype: int64

# %%
% rerun 32
# Out:
# No lines in history match specification

# %%
bk['marital'].value_counts()
# Out:
# married       2509
# single        1153
# divorced       445
# unknown         11
# divorceded       1
# Name: marital, dtype: int64

# %%
bk['education'].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                574
# professional.course     535
# basic.4y                429
# basic.6y                227
# unknown                 167
# basic.6yes                1
# illiterate                1
# Name: education, dtype: int64

# %%
# correct typos
bk.loc[bk.marital == "divorceded", 'marital'] = "divorced"
bk.marital.value_counts()
# Out:
# married     2509
# single      1153
# divorced     446
# unknown       11
# Name: marital, dtype: int64

# %%
bk.loc[bk.education == "basic.6yes", 'education'] = "basic.6y"
bk.education.value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                574
# professional.course     535
# basic.4y                429
# basic.6y                228
# unknown                 167
# illiterate                1
# Name: education, dtype: int64

# %%
bk['default'].value_counts()
# Out:
# no         3314
# unknown     803
# noo           1
# yes           1
# Name: default, dtype: int64

# %%
bk.loc[bk.default == "noo", 'default'] = "no"
bk['default'].value_counts()
# Out:
# no         3315
# unknown     803
# yes           1
# Name: default, dtype: int64

# %%
bk['housing'].value_counts()
# Out:
# yes        2174
# no         1839
# unknown     105
# yess          1
# Name: housing, dtype: int64

# %%
bk.loc[bk.housing == "yess", 'housing'] = "yes"
bk['housing'].value_counts()
# Out:
# yes        2175
# no         1839
# unknown     105
# Name: housing, dtype: int64

# %%
bk['loan'].value_counts()
# the "loan" attribute does not contain any typos
# Out:
# no         3349
# yes         665
# unknown     105
# Name: loan, dtype: int64

# %%
bk['contact'].value_counts()
# the "contact" attribute does not contain any typos
# Out:
# cellular     2652
# telephone    1467
# Name: contact, dtype: int64

# %%
bk['month'].value_counts()
# Out:
# may    1378
# jul     711
# aug     636
# jun     530
# nov     446
# apr     215
# oct      69
# sep      64
# mar      48
# dec      22
# Name: month, dtype: int64

# %%
bk['day_of_week'].value_counts()
# Out:
# thu    860
# mon    855
# tue    841
# wed    795
# fri    768
# Name: day_of_week, dtype: int64

# %%
bk.loc[bk.duration == "-", 'duration'] = ""
bk['duration'].count()
# Out:
# 4119

# %%
bk['poutcome'].value_counts()
# Out:
# nonexistent    3523
# failure         454
# success         142
# Name: poutcome, dtype: int64

# %%
bk['y'].value_counts()
# Out:
# no     3668
# yes     451
# Name: y, dtype: int64

# %%
bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# age               4116 non-null float64
# job               4119 non-null object
# marital           4119 non-null object
# education         4119 non-null object
# default           4119 non-null object
# housing           4119 non-null object
# loan              4119 non-null object
# contact           4119 non-null object
# month             4119 non-null object
# day_of_week       4119 non-null object
# duration          4119 non-null object
# campaign          4119 non-null int64
# pdays             4119 non-null int64
# previous          4119 non-null int64
# poutcome          4119 non-null object
# emp.var.rate      4119 non-null float64
# cons.price.idx    4116 non-null float64
# cons.conf.idx     4119 non-null float64
# euribor3m         4117 non-null float64
# nr.employed       4117 non-null float64
# y                 4119 non-null object
# dtypes: float64(6), int64(3), object(12)
# memory usage: 675.8+ KB

# %%
bk.describe()
# Out:
#                age     campaign        pdays     previous  emp.var.rate  \
# count  4116.000000  4119.000000  4119.000000  4119.000000   4119.000000
# mean     40.188533     2.537266   960.422190     0.190337      0.084972
# std      10.939885     2.568159   191.922786     0.541788      1.563114
# min      18.000000     1.000000     0.000000     0.000000     -3.400000
# 25%      32.000000     1.000000   999.000000     0.000000     -1.800000
# 50%      38.000000     2.000000   999.000000     0.000000      1.100000
# 75%      47.000000     3.000000   999.000000     0.000000      1.400000
# max     250.000000    35.000000   999.000000     6.000000      1.400000
#
#        cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count     4116.000000    4119.000000  4117.000000  4117.000000
# mean        93.579421     -40.499102     3.621787  5166.536386
# std          0.579464       4.594578     1.733619    73.637236
# min         92.201000     -50.800000     0.635000  4963.600000
# 25%         93.075000     -42.700000     1.334000  5099.100000
# 50%         93.749000     -41.800000     4.857000  5191.000000
# 75%         93.994000     -36.400000     4.961000  5228.100000
# max         94.767000     -26.900000     5.045000  5228.100000

# %%
bk['duration'] = bk['duration'].apply(pd.to_numeric)
bk.describe()
# for numeric attributes from "age" to "previous" plus "nr.employed", there should not be any negative values,
# all min values for these attributes are positive so they are good.
# for other typos such as impossible max values in 'age' can be corrected in the later sanity checks.
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4116.000000  4118.000000  4119.000000  4119.000000  4119.000000
# mean     40.188533   256.754978     2.537266   960.422190     0.190337
# std      10.939885   254.725819     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max     250.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4116.000000    4119.000000  4117.000000  4117.000000
# mean       0.084972       93.579421     -40.499102     3.621787  5166.536386
# std        1.563114        0.579464       4.594578     1.733619    73.637236
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %%
agesort = bk.sort_values('age',ascending=False,na_position='first')
agesort.head(10)
# max age has two typos, will be replaced by mean later.
# age has three missing values
# Out:
#         age          job   marital          education  default housing loan  \
# 36      NaN  blue-collar   married           basic.6y       no     yes   no
# 433     NaN       admin.    single  university.degree       no     yes   no
# 538     NaN   management   married        high.school       no     yes   no
# 394   250.0       admin.   married           basic.9y       no      no   no
# 385   143.0   unemployed   married           basic.4y       no      no   no
# 1215   88.0      retired  divorced           basic.4y       no     yes  yes
# 1796   86.0      retired   married            unknown  unknown     yes   no
# 696    86.0      retired   married            unknown  unknown     yes  yes
# 1123   85.0    housemaid  divorced           basic.4y  unknown     yes   no
# 150    82.0    housemaid   married           basic.4y       no      no   no
#
#         contact month day_of_week ...   campaign  pdays  previous  \
# 36    telephone   may         wed ...          1    999         0
# 433    cellular   aug         thu ...          1    999         0
# 538    cellular   aug         wed ...          1    999         0
# 394    cellular   aug         thu ...          1    999         0
# 385    cellular   may         wed ...          2    999         0
# 1215   cellular   mar         wed ...          2    999         0
# 1796   cellular   sep         tue ...          1    999         0
# 696    cellular   sep         tue ...          1      7         4
# 1123  telephone   oct         fri ...          2    999         0
# 150   telephone   sep         tue ...          3      3         2
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 36    nonexistent          1.1          93.994          -36.4      4.859
# 433   nonexistent          1.4          93.444          -36.1      4.963
# 538   nonexistent          1.4          93.444          -36.1      4.965
# 394   nonexistent          1.4          93.444          -36.1      4.968
# 385   nonexistent         -1.8          92.893          -46.2      1.334
# 1215  nonexistent         -1.8          92.843          -50.0      1.663
# 1796  nonexistent         -1.1          94.199          -37.5      0.877
# 696       success         -1.1          94.199          -37.5      0.877
# 1123  nonexistent         -3.4          92.431          -26.9      0.739
# 150       success         -1.1          94.199          -37.5      0.877
#
#       nr.employed    y
# 36         5191.0   no
# 433        5228.1   no
# 538        5228.1   no
# 394        5228.1   no
# 385        5099.1   no
# 1215       5099.1   no
# 1796       4963.6  yes
# 696        4963.6  yes
# 1123       5017.5   no
# 150        4963.6  yes
#
# [10 rows x 21 columns]

# %%
agesort.tail(8)
# min age is reasonable
# Out:
#        age          job marital    education  default housing loan    contact  \
# 1275  20.0      student  single  high.school       no      no   no   cellular
# 39    20.0      student  single      unknown       no      no   no   cellular
# 3268  20.0  blue-collar  single  high.school       no     yes   no   cellular
# 1377  20.0      student  single      unknown       no     yes  yes   cellular
# 1887  19.0      student  single  high.school  unknown     yes   no   cellular
# 1661  18.0      student  single      unknown       no     yes   no   cellular
# 899   18.0      student  single      unknown       no     yes  yes  telephone
# 477   18.0      student  single      unknown       no      no   no   cellular
#
#      month day_of_week ...   campaign  pdays  previous     poutcome  \
# 1275   nov         wed ...          2    999         0  nonexistent
# 39     oct         mon ...          3    999         3      failure
# 3268   may         wed ...          1    999         0  nonexistent
# 1377   apr         tue ...          2    999         0  nonexistent
# 1887   may         tue ...          4    999         0  nonexistent
# 1661   may         thu ...          1      7         2      success
# 899    aug         wed ...          1    999         0  nonexistent
# 477    sep         thu ...          1      3         1      success
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 1275         -3.4          92.649          -30.1      0.715       5017.5   no
# 39           -1.1          94.601          -49.5      0.977       4963.6   no
# 3268         -1.8          92.893          -46.2      1.334       5099.1   no
# 1377         -1.8          93.075          -47.1      1.405       5099.1   no
# 1887         -1.8          92.893          -46.2      1.344       5099.1   no
# 1661         -1.8          93.876          -40.0      0.677       5008.7   no
# 899          -1.7          94.027          -38.3      0.900       4991.6   no
# 477          -3.4          92.379          -29.8      0.809       5017.5  yes
#
# [8 rows x 21 columns]

# %%
bk.loc[(bk['age'] >= 100)]
# Out:
#        age         job  marital education default housing loan   contact  \
# 385  143.0  unemployed  married  basic.4y      no      no   no  cellular
# 394  250.0      admin.  married  basic.9y      no      no   no  cellular
#
#     month day_of_week ...  campaign  pdays  previous     poutcome  \
# 385   may         wed ...         2    999         0  nonexistent
# 394   aug         thu ...         1    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 385         -1.8          92.893          -46.2      1.334       5099.1  no
# 394          1.4          93.444          -36.1      4.968       5228.1  no
#
# [2 rows x 21 columns]

# %%
bk.loc[bk.age >= 100, 'age'] = None
bk.take([385,394])
# Out:
#      age         job  marital education default housing loan   contact month  \
# 385  NaN  unemployed  married  basic.4y      no      no   no  cellular   may
# 394  NaN      admin.  married  basic.9y      no      no   no  cellular   aug
#
#     day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 385         wed ...         2    999         0  nonexistent         -1.8
# 394         thu ...         1    999         0  nonexistent          1.4
#
#      cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 385          92.893          -46.2      1.334       5099.1  no
# 394          93.444          -36.1      4.968       5228.1  no
#
# [2 rows x 21 columns]

# %%
bk['job'].str.strip()
bk['job'].str.lower()
# Out:
# 0         blue-collar
# 1            services
# 2            services
# 3            services
# 4              admin.
# 5            services
# 6              admin.
# 7        entrepreneur
# 8            services
# 9         blue-collar
# 10           services
# 11      self-employed
# 12             admin.
# 13        blue-collar
# 14             admin.
# 15           services
# 16             admin.
# 17             admin.
# 18       entrepreneur
# 19        blue-collar
# 20           services
# 21         technician
# 22         technician
# 23         management
# 24         technician
# 25         technician
# 26         technician
# 27        blue-collar
# 28             admin.
# 29             admin.
#             ...
# 4089           admin.
# 4090      blue-collar
# 4091       management
# 4092      blue-collar
# 4093          retired
# 4094      blue-collar
# 4095           admin.
# 4096         services
# 4097      blue-collar
# 4098        housemaid
# 4099           admin.
# 4100           admin.
# 4101     entrepreneur
# 4102      blue-collar
# 4103         services
# 4104       technician
# 4105        housemaid
# 4106     entrepreneur
# 4107           admin.
# 4108           admin.
# 4109          retired
# 4110        housemaid
# 4111       technician
# 4112       technician
# 4113           admin.
# 4114           admin.
# 4115           admin.
# 4116          student
# 4117           admin.
# 4118       management
# Name: job, Length: 4119, dtype: object

# %%
bk['marital'].str.strip()
bk['marital'].str.lower()
# Out:
# 0        married
# 1         single
# 2        married
# 3        married
# 4        married
# 5         single
# 6         single
# 7        married
# 8       divorced
# 9        married
# 10        single
# 11        single
# 12       married
# 13       married
# 14        single
# 15        single
# 16      divorced
# 17      divorced
# 18       married
# 19       married
# 20       married
# 21      divorced
# 22        single
# 23       married
# 24       married
# 25       married
# 26      divorced
# 27       married
# 28        single
# 29       married
#           ...
# 4089      single
# 4090     married
# 4091     married
# 4092      single
# 4093     married
# 4094     married
# 4095      single
# 4096     married
# 4097    divorced
# 4098      single
# 4099    divorced
# 4100    divorced
# 4101      single
# 4102      single
# 4103     married
# 4104    divorced
# 4105     married
# 4106    divorced
# 4107     married
# 4108     married
# 4109     married
# 4110    divorced
# 4111     married
# 4112      single
# 4113      single
# 4114     married
# 4115     married
# 4116      single
# 4117     married
# 4118      single
# Name: marital, Length: 4119, dtype: object

# %%
bk['education'].str.strip()
bk['education'].str.lower()
# Out:
# 0                  basic.9y
# 1               high.school
# 2               high.school
# 3                  basic.9y
# 4         university.degree
# 5         university.degree
# 6         university.degree
# 7         university.degree
# 8       professional.course
# 9                  basic.9y
# 10                 basic.6y
# 11                 basic.4y
# 12              high.school
# 13                 basic.4y
# 14              high.school
# 15        university.degree
# 16        university.degree
# 17        university.degree
# 18        university.degree
# 19                 basic.4y
# 20                 basic.6y
# 21              high.school
# 22        university.degree
# 23              high.school
# 24      professional.course
# 25      professional.course
# 26      professional.course
# 27                 basic.6y
# 28                  unknown
# 29        university.degree
#                ...
# 4089      university.degree
# 4090               basic.4y
# 4091            high.school
# 4092            high.school
# 4093               basic.4y
# 4094               basic.4y
# 4095      university.degree
# 4096            high.school
# 4097               basic.9y
# 4098      university.degree
# 4099            high.school
# 4100            high.school
# 4101      university.degree
# 4102               basic.9y
# 4103            high.school
# 4104    professional.course
# 4105               basic.4y
# 4106               basic.9y
# 4107      university.degree
# 4108      university.degree
# 4109            high.school
# 4110               basic.6y
# 4111      university.degree
# 4112    professional.course
# 4113      university.degree
# 4114               basic.6y
# 4115            high.school
# 4116            high.school
# 4117            high.school
# 4118            high.school
# Name: education, Length: 4119, dtype: object

# %%
bk['default'].str.strip()
bk['default'].str.lower()
# Out:
# 0            no
# 1            no
# 2            no
# 3            no
# 4            no
# 5            no
# 6            no
# 7       unknown
# 8            no
# 9       unknown
# 10      unknown
# 11           no
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18      unknown
# 19           no
# 20      unknown
# 21           no
# 22           no
# 23           no
# 24      unknown
# 25           no
# 26           no
# 27      unknown
# 28      unknown
# 29           no
#          ...
# 4089         no
# 4090    unknown
# 4091    unknown
# 4092         no
# 4093    unknown
# 4094         no
# 4095         no
# 4096         no
# 4097         no
# 4098         no
# 4099         no
# 4100         no
# 4101         no
# 4102    unknown
# 4103         no
# 4104         no
# 4105    unknown
# 4106         no
# 4107    unknown
# 4108         no
# 4109         no
# 4110    unknown
# 4111         no
# 4112         no
# 4113         no
# 4114         no
# 4115         no
# 4116         no
# 4117         no
# 4118         no
# Name: default, Length: 4119, dtype: object

# %%
bk['housing'].str.strip()
bk['housing'].str.lower()
# Out:
# 0           yes
# 1            no
# 2           yes
# 3       unknown
# 4           yes
# 5            no
# 6           yes
# 7           yes
# 8            no
# 9            no
# 10          yes
# 11           no
# 12           no
# 13          yes
# 14           no
# 15           no
# 16           no
# 17          yes
# 18          yes
# 19           no
# 20          yes
# 21           no
# 22          yes
# 23           no
# 24          yes
# 25          yes
# 26           no
# 27           no
# 28           no
# 29           no
#          ...
# 4089        yes
# 4090        yes
# 4091         no
# 4092         no
# 4093         no
# 4094        yes
# 4095         no
# 4096         no
# 4097         no
# 4098        yes
# 4099         no
# 4100         no
# 4101        yes
# 4102         no
# 4103         no
# 4104        yes
# 4105        yes
# 4106        yes
# 4107        yes
# 4108        yes
# 4109         no
# 4110    unknown
# 4111         no
# 4112        yes
# 4113        yes
# 4114        yes
# 4115        yes
# 4116         no
# 4117         no
# 4118        yes
# Name: housing, Length: 4119, dtype: object

# %%
bk['loan'].str.strip()
bk['loan'].str.lower()
# Out:
# 0            no
# 1            no
# 2            no
# 3       unknown
# 4            no
# 5            no
# 6            no
# 7            no
# 8            no
# 9            no
# 10           no
# 11           no
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18          yes
# 19          yes
# 20           no
# 21           no
# 22          yes
# 23          yes
# 24           no
# 25           no
# 26           no
# 27           no
# 28           no
# 29           no
#          ...
# 4089        yes
# 4090        yes
# 4091         no
# 4092         no
# 4093         no
# 4094         no
# 4095        yes
# 4096         no
# 4097         no
# 4098         no
# 4099         no
# 4100         no
# 4101         no
# 4102        yes
# 4103         no
# 4104         no
# 4105         no
# 4106         no
# 4107         no
# 4108         no
# 4109         no
# 4110    unknown
# 4111        yes
# 4112         no
# 4113         no
# 4114        yes
# 4115         no
# 4116         no
# 4117         no
# 4118         no
# Name: loan, Length: 4119, dtype: object

# %%
bk['contact'].str.strip()
bk['contact'].str.lower()
# Out:
# 0        cellular
# 1       telephone
# 2       telephone
# 3       telephone
# 4        cellular
# 5        cellular
# 6        cellular
# 7        cellular
# 8        cellular
# 9       telephone
# 10       cellular
# 11       cellular
# 12      telephone
# 13      telephone
# 14       cellular
# 15       cellular
# 16       cellular
# 17      telephone
# 18       cellular
# 19       cellular
# 20       cellular
# 21       cellular
# 22       cellular
# 23       cellular
# 24      telephone
# 25       cellular
# 26      telephone
# 27       cellular
# 28      telephone
# 29       cellular
#           ...
# 4089     cellular
# 4090    telephone
# 4091    telephone
# 4092    telephone
# 4093     cellular
# 4094     cellular
# 4095     cellular
# 4096    telephone
# 4097     cellular
# 4098     cellular
# 4099     cellular
# 4100     cellular
# 4101     cellular
# 4102    telephone
# 4103    telephone
# 4104     cellular
# 4105    telephone
# 4106     cellular
# 4107     cellular
# 4108    telephone
# 4109     cellular
# 4110    telephone
# 4111     cellular
# 4112     cellular
# 4113     cellular
# 4114     cellular
# 4115    telephone
# 4116     cellular
# 4117     cellular
# 4118     cellular
# Name: contact, Length: 4119, dtype: object

# %%
bk['month'].str.strip()
bk['month'].str.lower()
# Out:
# 0       may
# 1       may
# 2       jun
# 3       jun
# 4       nov
# 5       sep
# 6       sep
# 7       nov
# 8       nov
# 9       may
# 10      jul
# 11      jul
# 12      may
# 13      jun
# 14      may
# 15      jul
# 16      jul
# 17      jul
# 18      aug
# 19      jul
# 20      jul
# 21      mar
# 22      aug
# 23      aug
# 24      may
# 25      aug
# 26      may
# 27      may
# 28      may
# 29      aug
#        ...
# 4089    oct
# 4090    may
# 4091    may
# 4092    jul
# 4093    jul
# 4094    nov
# 4095    aug
# 4096    may
# 4097    aug
# 4098    aug
# 4099    aug
# 4100    apr
# 4101    jul
# 4102    jun
# 4103    may
# 4104    aug
# 4105    jul
# 4106    may
# 4107    aug
# 4108    may
# 4109    oct
# 4110    may
# 4111    jun
# 4112    nov
# 4113    nov
# 4114    jul
# 4115    jul
# 4116    may
# 4117    aug
# 4118    nov
# Name: month, Length: 4119, dtype: object

# %%
bk['day_of_week'].str.strip()
bk['day_of_week'].str.lower()
# Out:
# 0       fri
# 1       fri
# 2       wed
# 3       fri
# 4       mon
# 5       thu
# 6       mon
# 7       mon
# 8       tue
# 9       thu
# 10      thu
# 11      thu
# 12      wed
# 13      thu
# 14      fri
# 15      wed
# 16      wed
# 17      mon
# 18      mon
# 19      tue
# 20      tue
# 21      mon
# 22      wed
# 23      wed
# 24      fri
# 25      mon
# 26      wed
# 27      mon
# 28      thu
# 29      tue
#        ...
# 4089    fri
# 4090    tue
# 4091    thu
# 4092    wed
# 4093    tue
# 4094    mon
# 4095    fri
# 4096    mon
# 4097    tue
# 4098    thu
# 4099    tue
# 4100    fri
# 4101    mon
# 4102    fri
# 4103    mon
# 4104    mon
# 4105    tue
# 4106    tue
# 4107    wed
# 4108    thu
# 4109    wed
# 4110    fri
# 4111    fri
# 4112    thu
# 4113    thu
# 4114    thu
# 4115    fri
# 4116    mon
# 4117    fri
# 4118    wed
# Name: day_of_week, Length: 4119, dtype: object

# %%
bk['poutcome'].str.strip()
bk['poutcome'].str.lower()
# Out:
# 0       nonexistent
# 1       nonexistent
# 2       nonexistent
# 3       nonexistent
# 4       nonexistent
# 5           failure
# 6       nonexistent
# 7       nonexistent
# 8           failure
# 9       nonexistent
# 10      nonexistent
# 11      nonexistent
# 12      nonexistent
# 13      nonexistent
# 14      nonexistent
# 15      nonexistent
# 16      nonexistent
# 17      nonexistent
# 18      nonexistent
# 19      nonexistent
# 20      nonexistent
# 21          success
# 22      nonexistent
# 23      nonexistent
# 24      nonexistent
# 25      nonexistent
# 26      nonexistent
# 27          failure
# 28      nonexistent
# 29      nonexistent
#            ...
# 4089        failure
# 4090    nonexistent
# 4091    nonexistent
# 4092    nonexistent
# 4093    nonexistent
# 4094        success
# 4095    nonexistent
# 4096    nonexistent
# 4097    nonexistent
# 4098    nonexistent
# 4099    nonexistent
# 4100    nonexistent
# 4101    nonexistent
# 4102    nonexistent
# 4103    nonexistent
# 4104    nonexistent
# 4105    nonexistent
# 4106    nonexistent
# 4107    nonexistent
# 4108    nonexistent
# 4109    nonexistent
# 4110    nonexistent
# 4111        failure
# 4112    nonexistent
# 4113    nonexistent
# 4114    nonexistent
# 4115    nonexistent
# 4116        failure
# 4117    nonexistent
# 4118    nonexistent
# Name: poutcome, Length: 4119, dtype: object

# %%
bk['y'].str.strip()
bk['y'].str.lower()
# Out:
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# 5        no
# 6        no
# 7        no
# 8        no
# 9        no
# 10       no
# 11       no
# 12       no
# 13       no
# 14       no
# 15       no
# 16       no
# 17       no
# 18       no
# 19      yes
# 20       no
# 21      yes
# 22       no
# 23       no
# 24       no
# 25      yes
# 26       no
# 27       no
# 28       no
# 29       no
#        ...
# 4089    yes
# 4090     no
# 4091     no
# 4092     no
# 4093     no
# 4094     no
# 4095     no
# 4096     no
# 4097     no
# 4098     no
# 4099     no
# 4100     no
# 4101     no
# 4102     no
# 4103     no
# 4104     no
# 4105     no
# 4106     no
# 4107     no
# 4108     no
# 4109     no
# 4110     no
# 4111     no
# 4112     no
# 4113     no
# 4114     no
# 4115     no
# 4116     no
# 4117     no
# 4118     no
# Name: y, Length: 4119, dtype: object

# %%
# since impossible max age had been done when correcting typos, now this line will return zero rows as all ages are within a reasonable range.
bk.loc[(bk['age'] >= 100)]
#bk.loc[bk.age >= 100, 'age'] = None
#bk.take([385,394])
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# check if other numeric variables have negative values where it shouldn't.
bk.loc[(bk['duration'] <= 0)]
# Out:
#        age     job  marital    education default housing loan    contact  \
# 1950  39.0  admin.  married  high.school      no     yes   no  telephone
#
#      month day_of_week ...  campaign  pdays  previous     poutcome  \
# 1950   may         tue ...         4    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 1950          1.1          93.994          -36.4      4.857       5191.0  no
#
# [1 rows x 21 columns]

# %%
bk.duration.count()
# Out:
# 4118

# %%
bk['duration'][1950]
# at row index=1950, the duration has a value 0, this location is not a missing value.
# Out:
# 0.0

# %%
bk.loc[(bk['campaign'] <= 0)]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
bk.loc[(bk['pdays'] <=0)]
# pdays = 0 can by possible if the client has been contacted twice on the same day, and if the first time was contacted for the previous campaign
# and the second time was contacted for a current campaign activity.
# Out:
#        age       job   marital          education default housing loan  \
# 1046  48.0    admin.   married  university.degree      no     yes  yes
# 3127  44.0  services  divorced           basic.6y      no     yes   no
#
#        contact month day_of_week ...   campaign  pdays  previous  poutcome  \
# 1046  cellular   aug         wed ...          1      0         3   success
# 3127  cellular   aug         wed ...          3      0         1   success
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 1046         -1.7          94.027          -38.3        0.9       4991.6  yes
# 3127         -1.7          94.027          -38.3        0.9       4991.6  yes
#
# [2 rows x 21 columns]

# %%
bk.pdays.count()
# no missing values in "pdays", contains calue 0.
# Out:
# 4119

# %%
bk.loc[(bk['previous'] <= 0)]
# "previous" = 0 is reasonable if the client is a new client and hasn't been contacted before.
# Out:
#        age            job   marital            education  default  housing  \
# 0     30.0    blue-collar   married             basic.9y       no      yes
# 1     39.0       services    single          high.school       no       no
# 2     25.0       services   married          high.school       no      yes
# 3     38.0       services   married             basic.9y       no  unknown
# 4     47.0         admin.   married    university.degree       no      yes
# 6     32.0         admin.    single    university.degree       no      yes
# 7     41.0   entrepreneur   married    university.degree  unknown      yes
# 9     35.0    blue-collar   married             basic.9y  unknown       no
# 10    25.0       services    single             basic.6y  unknown      yes
# 11    36.0  self-employed    single             basic.4y       no       no
# 12    36.0         admin.   married          high.school       no       no
# 13    47.0    blue-collar   married             basic.4y       no      yes
# 14    29.0         admin.    single          high.school       no       no
# 15    27.0       services    single    university.degree       no       no
# 16    44.0         admin.  divorced    university.degree       no       no
# 17    46.0         admin.  divorced    university.degree       no      yes
# 18    45.0   entrepreneur   married    university.degree  unknown      yes
# 19    50.0    blue-collar   married             basic.4y       no       no
# 20    55.0       services   married             basic.6y  unknown      yes
# 22    29.0     technician    single    university.degree       no      yes
# 23    40.0     management   married          high.school       no       no
# 24    44.0     technician   married  professional.course  unknown      yes
# 25    38.0     technician   married  professional.course       no      yes
# 26    36.0     technician  divorced  professional.course       no       no
# 28    47.0         admin.    single              unknown  unknown       no
# 29    34.0         admin.   married    university.degree       no       no
# 31    33.0       services   married          high.school  unknown      yes
# 32    51.0     technician    single    university.degree       no       no
# 33    30.0    blue-collar    single             basic.4y  unknown      yes
# 34    48.0     technician   married    university.degree       no       no
# ...    ...            ...       ...                  ...      ...      ...
# 4084  30.0     unemployed    single          high.school       no       no
# 4085  42.0     technician    single             basic.9y       no      yes
# 4086  54.0     technician   married  professional.course       no      yes
# 4087  29.0         admin.   married    university.degree       no      yes
# 4090  43.0    blue-collar   married             basic.4y  unknown      yes
# 4091  38.0     management   married          high.school  unknown       no
# 4092  30.0    blue-collar    single          high.school       no       no
# 4093  56.0        retired   married             basic.4y  unknown       no
# 4095  36.0         admin.    single    university.degree       no       no
# 4096  33.0       services   married          high.school       no       no
# 4097  41.0    blue-collar  divorced             basic.9y       no       no
# 4098  34.0      housemaid    single    university.degree       no      yes
# 4099  58.0         admin.  divorced          high.school       no       no
# 4100  41.0         admin.  divorced          high.school       no       no
# 4101  35.0   entrepreneur    single    university.degree       no      yes
# 4102  31.0    blue-collar    single             basic.9y  unknown       no
# 4103  43.0       services   married          high.school       no       no
# 4104  42.0     technician  divorced  professional.course       no      yes
# 4105  47.0      housemaid   married             basic.4y  unknown      yes
# 4106  45.0   entrepreneur  divorced             basic.9y       no      yes
# 4107  36.0         admin.   married    university.degree  unknown      yes
# 4108  32.0         admin.   married    university.degree       no      yes
# 4109  63.0        retired   married          high.school       no       no
# 4110  53.0      housemaid  divorced             basic.6y  unknown  unknown
# 4112  31.0     technician    single  professional.course       no      yes
# 4113  31.0         admin.    single    university.degree       no      yes
# 4114  30.0         admin.   married             basic.6y       no      yes
# 4115  39.0         admin.   married          high.school       no      yes
# 4117  58.0         admin.   married          high.school       no       no
# 4118  34.0     management    single          high.school       no      yes
#
#          loan    contact month day_of_week ...   campaign  pdays  previous  \
# 0          no   cellular   may         fri ...          2    999         0
# 1          no  telephone   may         fri ...          4    999         0
# 2          no  telephone   jun         wed ...          1    999         0
# 3     unknown  telephone   jun         fri ...          3    999         0
# 4          no   cellular   nov         mon ...          1    999         0
# 6          no   cellular   sep         mon ...          4    999         0
# 7          no   cellular   nov         mon ...          2    999         0
# 9          no  telephone   may         thu ...          1    999         0
# 10         no   cellular   jul         thu ...          1    999         0
# 11         no   cellular   jul         thu ...          1    999         0
# 12         no  telephone   may         wed ...          2    999         0
# 13         no  telephone   jun         thu ...          2    999         0
# 14         no   cellular   may         fri ...          2    999         0
# 15         no   cellular   jul         wed ...          2    999         0
# 16         no   cellular   jul         wed ...          6    999         0
# 17         no  telephone   jul         mon ...          4    999         0
# 18        yes   cellular   aug         mon ...          2    999         0
# 19        yes   cellular   jul         tue ...          1    999         0
# 20         no   cellular   jul         tue ...          6    999         0
# 22        yes   cellular   aug         wed ...          3    999         0
# 23        yes   cellular   aug         wed ...          1    999         0
# 24         no  telephone   may         fri ...          7    999         0
# 25         no   cellular   aug         mon ...          1    999         0
# 26         no  telephone   may         wed ...          1    999         0
# 28         no  telephone   may         thu ...          1    999         0
# 29         no   cellular   aug         tue ...          1    999         0
# 31         no  telephone   jun         mon ...          3    999         0
# 32         no   cellular   jun         fri ...          2    999         0
# 33         no  telephone   jun         tue ...          1    999         0
# 34         no   cellular   aug         thu ...          7    999         0
# ...       ...        ...   ...         ... ...        ...    ...       ...
# 4084       no   cellular   may         fri ...         11    999         0
# 4085       no  telephone   may         wed ...          2    999         0
# 4086      yes  telephone   may         mon ...          2    999         0
# 4087       no  telephone   may         thu ...          1    999         0
# 4090      yes  telephone   may         tue ...          2    999         0
# 4091       no  telephone   may         thu ...          2    999         0
# 4092       no  telephone   jul         wed ...          1    999         0
# 4093       no   cellular   jul         tue ...          3    999         0
# 4095      yes   cellular   aug         fri ...          2    999         0
# 4096       no  telephone   may         mon ...          2    999         0
# 4097       no   cellular   aug         tue ...          1    999         0
# 4098       no   cellular   aug         thu ...          3    999         0
# 4099       no   cellular   aug         tue ...          1    999         0
# 4100       no   cellular   apr         fri ...          1    999         0
# 4101       no   cellular   jul         mon ...          5    999         0
# 4102      yes  telephone   jun         fri ...          2    999         0
# 4103       no  telephone   may         mon ...          1    999         0
# 4104       no   cellular   aug         mon ...          1    999         0
# 4105       no  telephone   jul         tue ...          2    999         0
# 4106       no   cellular   may         tue ...          3    999         0
# 4107       no   cellular   aug         wed ...         11    999         0
# 4108       no  telephone   may         thu ...          5    999         0
# 4109       no   cellular   oct         wed ...          1    999         0
# 4110  unknown  telephone   may         fri ...          2    999         0
# 4112       no   cellular   nov         thu ...          1    999         0
# 4113       no   cellular   nov         thu ...          1    999         0
# 4114      yes   cellular   jul         thu ...          1    999         0
# 4115       no  telephone   jul         fri ...          1    999         0
# 4117       no   cellular   aug         fri ...          1    999         0
# 4118       no   cellular   nov         wed ...          1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0     nonexistent         -1.8          92.893          -46.2      1.313
# 1     nonexistent          1.1          93.994          -36.4      4.855
# 2     nonexistent          1.4          94.465          -41.8      4.962
# 3     nonexistent          1.4          94.465          -41.8      4.959
# 4     nonexistent         -0.1          93.200          -42.0      4.191
# 6     nonexistent         -1.1          94.199          -37.5      0.879
# 7     nonexistent         -0.1          93.200          -42.0      4.191
# 9     nonexistent          1.1          93.994          -36.4      4.855
# 10    nonexistent          1.4          93.918          -42.7      4.958
# 11    nonexistent          1.4          93.918          -42.7      4.968
# 12    nonexistent          1.1          93.994          -36.4      4.859
# 13    nonexistent          1.4          94.465          -41.8      4.958
# 14    nonexistent         -1.8          92.893          -46.2      1.313
# 15    nonexistent          1.4          93.918          -42.7      4.963
# 16    nonexistent          1.4          93.918          -42.7      4.957
# 17    nonexistent          1.4          93.918          -42.7      4.962
# 18    nonexistent          1.4          93.444          -36.1      4.965
# 19    nonexistent          1.4          93.918          -42.7      4.961
# 20    nonexistent          1.4          93.918          -42.7      4.962
# 22    nonexistent          1.4          93.444          -36.1      4.967
# 23    nonexistent          1.4          93.444          -36.1      4.965
# 24    nonexistent          1.1          93.994          -36.4      4.864
# 25    nonexistent          1.4          93.444          -36.1      4.965
# 26    nonexistent          1.1          93.994          -36.4      4.856
# 28    nonexistent          1.1          93.994          -36.4      4.860
# 29    nonexistent          1.4          93.444          -36.1      4.963
# 31    nonexistent          1.4          94.465          -41.8      4.865
# 32    nonexistent         -2.9          92.963          -40.8      1.268
# 33    nonexistent          1.4          94.465          -41.8      4.864
# 34    nonexistent          1.4          93.444          -36.1      4.962
# ...           ...          ...             ...            ...        ...
# 4084  nonexistent         -1.8          92.893          -46.2      1.250
# 4085  nonexistent          1.1          93.994          -36.4      4.857
# 4086  nonexistent          1.1          93.994          -36.4      4.857
# 4087  nonexistent          1.1          93.994          -36.4      4.860
# 4090  nonexistent          1.1          93.994          -36.4      4.857
# 4091  nonexistent          1.1          93.994          -36.4      4.860
# 4092  nonexistent          1.4          93.918          -42.7      4.956
# 4093  nonexistent          1.4          93.918          -42.7      4.961
# 4095  nonexistent          1.4          93.444          -36.1      4.963
# 4096  nonexistent          1.1          93.994          -36.4      4.857
# 4097  nonexistent          1.4          93.444          -36.1      4.963
# 4098  nonexistent          1.4          93.444          -36.1      4.963
# 4099  nonexistent          1.4          93.444          -36.1      4.963
# 4100  nonexistent         -1.8          93.075          -47.1      1.405
# 4101  nonexistent          1.4          93.918          -42.7      4.960
# 4102  nonexistent          1.4          94.465          -41.8      4.959
# 4103  nonexistent          1.1          93.994          -36.4      4.857
# 4104  nonexistent          1.4          93.444          -36.1      4.970
# 4105  nonexistent          1.4          93.918          -42.7      4.961
# 4106  nonexistent         -1.8          92.893          -46.2      1.344
# 4107  nonexistent          1.4          93.444          -36.1      4.964
# 4108  nonexistent         -1.8          92.893          -46.2      1.266
# 4109  nonexistent         -3.4          92.431          -26.9      0.740
# 4110  nonexistent          1.1          93.994          -36.4      4.855
# 4112  nonexistent         -0.1          93.200          -42.0      4.076
# 4113  nonexistent         -0.1          93.200          -42.0      4.076
# 4114  nonexistent          1.4          93.918          -42.7      4.958
# 4115  nonexistent          1.4          93.918          -42.7      4.959
# 4117  nonexistent          1.4          93.444          -36.1      4.966
# 4118  nonexistent         -0.1          93.200          -42.0      4.120
#
#       nr.employed    y
# 0          5099.1   no
# 1          5191.0   no
# 2          5228.1   no
# 3          5228.1   no
# 4          5195.8   no
# 6          4963.6   no
# 7          5195.8   no
# 9          5191.0   no
# 10         5228.1   no
# 11         5228.1   no
# 12         5191.0   no
# 13         5228.1   no
# 14         5099.1   no
# 15         5228.1   no
# 16         5228.1   no
# 17         5228.1   no
# 18         5228.1   no
# 19         5228.1  yes
# 20         5228.1   no
# 22         5228.1   no
# 23         5228.1   no
# 24         5191.0   no
# 25         5228.1  yes
# 26         5191.0   no
# 28         5191.0   no
# 29         5228.1   no
# 31         5228.1   no
# 32         5076.2   no
# 33         5228.1   no
# 34         5228.1   no
# ...           ...  ...
# 4084       5099.1   no
# 4085       5191.0   no
# 4086       5191.0   no
# 4087       5191.0   no
# 4090       5191.0   no
# 4091       5191.0   no
# 4092       5228.1   no
# 4093       5228.1   no
# 4095       5228.1   no
# 4096       5191.0   no
# 4097       5228.1   no
# 4098       5228.1   no
# 4099       5228.1   no
# 4100       5099.1   no
# 4101       5228.1   no
# 4102       5228.1   no
# 4103       5191.0   no
# 4104       5228.1   no
# 4105       5228.1   no
# 4106       5099.1   no
# 4107       5228.1   no
# 4108       5099.1   no
# 4109       5017.5   no
# 4110       5191.0   no
# 4112       5195.8   no
# 4113       5195.8   no
# 4114       5228.1   no
# 4115       5228.1   no
# 4117       5228.1   no
# 4118       5195.8   no
#
# [3523 rows x 21 columns]

# %%
bk.loc[(bk['nr.employed'] <= 0)]
# number of employees are all postivie which is reasonable.
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
bk.describe()
# all previous sanity checks can be viewed in this describe too, ie.min value all greater than or equal to zero for "age" to "previous" and "nr.employed"
# min(cons.conf.idx) is -50.8 can be reasonable if lack of confidence is measured by negative indexes.Similiar to emp.var.rate
# mas(cons.conf.idx) is -26.9, being negative is reasonable if interpreted as the most confident client in this dataset still feels lack of confidence.
# max(duration) is 3643 seconds which is about one hour so is reasonable.
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4114.000000  4118.000000  4119.000000  4119.000000  4119.000000
# mean     40.112543   256.754978     2.537266   960.422190     0.190337
# std      10.317980   254.725819     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4116.000000    4119.000000  4117.000000  4117.000000
# mean       0.084972       93.579421     -40.499102     3.621787  5166.536386
# std        1.563114        0.579464       4.594578     1.733619    73.637236
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %%
# from the above describe() table, we can see which numeric attributes have missing values
# bk totally has 4119 rows, hence:
# 5 missing values in 'age'
# 1 missing value in 'duration'
# 3 missing values in 'cons.price.idx'
# 2 missing values in both 'euribor3m' and 'nr.employed'

# %%
# as rows containing NaN for 'age' was computed earlier, now can locate these missing values straight away
bk.take([36,433,538,394,385])
# Out:
#      age          job  marital          education default housing loan  \
# 36   NaN  blue-collar  married           basic.6y      no     yes   no
# 433  NaN       admin.   single  university.degree      no     yes   no
# 538  NaN   management  married        high.school      no     yes   no
# 394  NaN       admin.  married           basic.9y      no      no   no
# 385  NaN   unemployed  married           basic.4y      no      no   no
#
#        contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 36   telephone   may         wed ...         1    999         0  nonexistent
# 433   cellular   aug         thu ...         1    999         0  nonexistent
# 538   cellular   aug         wed ...         1    999         0  nonexistent
# 394   cellular   aug         thu ...         1    999         0  nonexistent
# 385   cellular   may         wed ...         2    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 36           1.1          93.994          -36.4      4.859       5191.0  no
# 433          1.4          93.444          -36.1      4.963       5228.1  no
# 538          1.4          93.444          -36.1      4.965       5228.1  no
# 394          1.4          93.444          -36.1      4.968       5228.1  no
# 385         -1.8          92.893          -46.2      1.334       5099.1  no
#
# [5 rows x 21 columns]

# %%
bk.count()
# all other categorical attributes do not contain missing values
# because they have 4119 rows the same as the total number of rows in bk.
# Out:
# age               4114
# job               4119
# marital           4119
# education         4119
# default           4119
# housing           4119
# loan              4119
# contact           4119
# month             4119
# day_of_week       4119
# duration          4118
# campaign          4119
# pdays             4119
# previous          4119
# poutcome          4119
# emp.var.rate      4119
# cons.price.idx    4116
# cons.conf.idx     4119
# euribor3m         4117
# nr.employed       4117
# y                 4119
# dtype: int64

# %%
bk.mean(axis = 0)
# print the column wise mean for respective attributes
# Out:
# age                 40.112543
# duration           256.754978
# campaign             2.537266
# pdays              960.422190
# previous             0.190337
# emp.var.rate         0.084972
# cons.price.idx      93.579421
# cons.conf.idx      -40.499102
# euribor3m            3.621787
# nr.employed       5166.536386
# dtype: float64

# %%
bk.take([36,433,538,394,385])
# Out:
#      age          job  marital          education default housing loan  \
# 36   NaN  blue-collar  married           basic.6y      no     yes   no
# 433  NaN       admin.   single  university.degree      no     yes   no
# 538  NaN   management  married        high.school      no     yes   no
# 394  NaN       admin.  married           basic.9y      no      no   no
# 385  NaN   unemployed  married           basic.4y      no      no   no
#
#        contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 36   telephone   may         wed ...         1    999         0  nonexistent
# 433   cellular   aug         thu ...         1    999         0  nonexistent
# 538   cellular   aug         wed ...         1    999         0  nonexistent
# 394   cellular   aug         thu ...         1    999         0  nonexistent
# 385   cellular   may         wed ...         2    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 36           1.1          93.994          -36.4      4.859       5191.0  no
# 433          1.4          93.444          -36.1      4.963       5228.1  no
# 538          1.4          93.444          -36.1      4.965       5228.1  no
# 394          1.4          93.444          -36.1      4.968       5228.1  no
# 385         -1.8          92.893          -46.2      1.334       5099.1  no
#
# [5 rows x 21 columns]

# %%
bk['age'].fillna(bk['age'].mean(axis = 0),inplace = True)
print(bk['age'][36])
print(bk['age'][433])
print(bk['age'][538])
print(bk['age'][394])
print(bk['age'][385])
# Out:
# 40.11254253767623
# 40.11254253767623
# 40.11254253767623
# 40.11254253767623
# 40.11254253767623

# %%
bk.take([36,433,538,394,385])
# Out:
#            age          job  marital          education default housing loan  \
# 36   40.112543  blue-collar  married           basic.6y      no     yes   no
# 433  40.112543       admin.   single  university.degree      no     yes   no
# 538  40.112543   management  married        high.school      no     yes   no
# 394  40.112543       admin.  married           basic.9y      no      no   no
# 385  40.112543   unemployed  married           basic.4y      no      no   no
#
#        contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 36   telephone   may         wed ...         1    999         0  nonexistent
# 433   cellular   aug         thu ...         1    999         0  nonexistent
# 538   cellular   aug         wed ...         1    999         0  nonexistent
# 394   cellular   aug         thu ...         1    999         0  nonexistent
# 385   cellular   may         wed ...         2    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 36           1.1          93.994          -36.4      4.859       5191.0  no
# 433          1.4          93.444          -36.1      4.963       5228.1  no
# 538          1.4          93.444          -36.1      4.965       5228.1  no
# 394          1.4          93.444          -36.1      4.968       5228.1  no
# 385         -1.8          92.893          -46.2      1.334       5099.1  no
#
# [5 rows x 21 columns]

# %%
bk.loc[bk['duration'] == None]
# row containing a nan duration cannot be shown
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
nans = lambda bk: bk[bk.isnull().any(axis=1)]
nans(bk)
# Out:
#       age            job   marital          education  default housing loan  \
# 21   39.0     technician  divorced        high.school       no      no   no
# 30   38.0     technician   married  university.degree       no     yes  yes
# 44   32.0      housemaid   married           basic.4y       no     yes  yes
# 77   38.0  self-employed    single  university.degree       no      no   no
# 193  47.0       services    single           basic.9y       no      no   no
# 249  44.0         admin.   married        high.school       no      no   no
# 303  24.0         admin.    single        high.school  unknown     yes   no
# 678  39.0    blue-collar   married           basic.6y       no      no   no
#
#        contact month day_of_week ...   campaign  pdays  previous     poutcome  \
# 21    cellular   mar         mon ...          1     12         2      success
# 30    cellular   mar         tue ...          1    999         1      failure
# 44    cellular   may         fri ...          1    999         0  nonexistent
# 77   telephone   may         thu ...          2    999         0  nonexistent
# 193   cellular   nov         tue ...          2    999         0  nonexistent
# 249  telephone   may         wed ...          3    999         0  nonexistent
# 303  telephone   jul         thu ...          1    999         0  nonexistent
# 678  telephone   may         thu ...          1    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 21          -1.8          93.369          -34.8      0.639          NaN  yes
# 30          -1.8          92.843          -50.0      1.687          NaN   no
# 44          -1.8          92.893          -46.2        NaN       5099.1   no
# 77           1.1             NaN          -36.4      4.855       5191.0   no
# 193         -0.1          93.200          -42.0        NaN       5195.8   no
# 249          1.1             NaN          -36.4      4.856       5191.0   no
# 303          1.4             NaN          -42.7      4.958       5228.1   no
# 678          1.1          93.994          -36.4      4.855       5191.0   no
#
# [8 rows x 21 columns]

# %%
print(bk['duration'][21])
print(bk['duration'][678])
# Out:
# 222.0
# nan

# %%
bk['duration'].fillna(bk['duration'].mean(axis = 0),inplace = True)
print(bk['duration'][678])
# Out:
# 256.75497814473044

# %%
print(bk['cons.price.idx'][77])
print(bk['cons.price.idx'][249])
print(bk['cons.price.idx'][303])
# Out:
# nan
# nan
# nan

# %%
bk['cons.price.idx'].fillna(bk['cons.price.idx'].mean(axis = 0),inplace = True)
bk['euribor3m'].fillna(bk['euribor3m'].mean(axis = 0),inplace = True)
bk['nr.employed'].fillna(bk['nr.employed'].mean(axis = 0),inplace = True)

# %%
print(bk['cons.price.idx'][77])
print(bk['cons.price.idx'][249])
print(bk['cons.price.idx'][303])
# Out:
# 93.5794207968932
# 93.5794207968932
# 93.5794207968932

# %%
print(bk['euribor3m'][44])
print(bk['euribor3m'][193])
# Out:
# 3.621787223706576
# 3.621787223706576

# %%
print(bk['nr.employed'][21])
print(bk['nr.employed'][30])
# Out:
# 5166.536385717834
# 5166.536385717834

# %%
nans = lambda bk: bk[bk.isnull().any(axis=1)]
nans(bk)
# the dataset contains no more missing values.
# all missing values are replaced with column-wise mean.
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
bk.groupby(['y']).mean()
# obviously longer duration of contact is associated with successful subscription of term deposits.
# Out:
#            age    duration  campaign       pdays  previous  emp.var.rate  \
# y
# no   39.894101  219.372616  2.605780  982.763086  0.141767      0.240185
# yes  41.889135  560.787140  1.980044  778.722838  0.585366     -1.177384
#
#      cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# y
# no        93.599358     -40.586723   3.803311  5175.520457
# yes       93.417268     -39.786475   2.145448  5093.468595

# %%
bk.info()
# all missing values are filled, all datatypes are correct.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# age               4119 non-null float64
# job               4119 non-null object
# marital           4119 non-null object
# education         4119 non-null object
# default           4119 non-null object
# housing           4119 non-null object
# loan              4119 non-null object
# contact           4119 non-null object
# month             4119 non-null object
# day_of_week       4119 non-null object
# duration          4119 non-null float64
# campaign          4119 non-null int64
# pdays             4119 non-null int64
# previous          4119 non-null int64
# poutcome          4119 non-null object
# emp.var.rate      4119 non-null float64
# cons.price.idx    4119 non-null float64
# cons.conf.idx     4119 non-null float64
# euribor3m         4119 non-null float64
# nr.employed       4119 non-null float64
# y                 4119 non-null object
# dtypes: float64(7), int64(3), object(11)
# memory usage: 675.8+ KB
